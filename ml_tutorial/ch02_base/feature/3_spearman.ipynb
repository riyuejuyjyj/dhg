# %%
import pandas  as pd

# %%
# 每周学习时长
X = [[5],[8],[10],[12],[15],[3],[7],[9],[14],[6]]
Y = [55,65,70,75,85,50,60,72,80,58]

X = pd.DataFrame(X)
y = pd.Series(Y)
print("X",X)
print("Y",y)
# Out:
# X     0
# 0   5
# 1   8
# 2  10
# 3  12
# 4  15
# 5   3
# 6   7
# 7   9
# 8  14
# 9   6
# Y 0    55
# 1    65
# 2    70
# 3    75
# 4    85
# 5    50
# 6    60
# 7    72
# 8    80
# 9    58
# dtype: int64

# %%
print(X.corrwith(y,method="spearman")) # type: ignore
# Out:
# 0    0.987879
# dtype: float64
